# %%
import numpy as np
import pandas as pd

# %%
#Data Importing

# %%
df = pd.read_csv(r'C:\Users\Nibras\OneDrive\Desktop\covishieldtamilnadu.csv',header=None)

# %%
df.head(10)
# Out:
#      0                     1                       2   \
# 0  S.No  Health Unit District  1stDosageCovishieldHCW
# 1     1            Aranthangi                    2364
# 2     2            Aranthangi                    2365
# 3     3            Aranthangi                    2365
# 4     4              Ariyalur                    4044
# 5     5              Ariyalur                    4044
# 6     6              Ariyalur                    4044
# 7     7                 Attur                    5542
# 8     8                 Attur                    5542
# 9     9                 Attur                    5542
#
#                         3                        4                       5   \
# 0   2ndDosageCovishieldHCW   1stDosageCovishieldFLW  2ndDosageCovishieldFLW
# 1                     1226                     2171                     802
# 2                     1226                     2172                     803
# 3                     1226                     2173                     835
# 4                     2577                     8940                    4473
# 5                     2577                     8954                    4473
# 6                     2578                     8954                    4473
# 7                     4869                     9922                    3644
# 8                     4874                     9922                    3644
# 9                     4874                     9922                    3645
#
#                         6                          7   \
# 0  1stDoseCovishield18to44   2ndDoseCovishield18to44
# 1                      210                          0
# 2                     1560                          0
# 3                     4248                          0
# 4                      385                          0
# 5                     2079                          0
# 6                     3486                          0
# 7                     1235                          0
# 8                     6404                          0
# 9                     9516                          0
#
#                                      8   \
# 0  1stDoseCovishield45to60Comorbidities
# 1                                 15407
# 2                                 15709
# 3                                 15886
# 4                                 16008
# 5                                 16453
# 6                                 16700
# 7                                 65777
# 8                                 66400
# 9                                 66912
#
#                                         9   \
# 0   2ndDosageCovishield45to60Comorbidities
# 1                                     4002
# 2                                     4020
# 3                                     4028
# 4                                     2783
# 5                                     2786
# 6                                     2793
# 7                                    17566
# 8                                    17625
# 9                                    17700
#
#                                     10                                   11  \
# 0  1stDosageCovishield60+Comorbidities  2ndDosageCovishield60+Comorbidities
# 1                                 9623                                 2409
# 2                                 9681                                 2412
# 3                                 9741                                 2415
# 4                                11216                                 2595
# 5                                11403                                 2601
# 6                                11493                                 2601
# 7                                38731                                10427
# 8                                38880                                10444
# 9                                39009                                10459
#
#                        12                      13          14
# 0  Total1stDoseCovishield  Total2ndDoseCovishield        Date
# 1                   29775                    8439  24-05-2021
# 2                   31487                    8461  25-05-2021
# 3                   34413                    8504  26-05-2021
# 4                   40593                   12428  24-05-2021
# 5                   42933                   12437  25-05-2021
# 6                   44677                   12445  26-05-2021
# 7                  121207                   36506  24-05-2021
# 8                  127148                   36587  25-05-2021
# 9                  130901                   36678  26-05-2021

# %%
#Data Cleaning#

# %%
headers = ["S.No", "Health_Unit_District","1stDosageCovishieldHCW","2ndDosageCovishieldHCW","1stDosageCovishieldFLW","2ndDosageCovishieldFLW","1stDoseCovishield18to44","2ndDoseCovishield18to44","1stDoseCovishield45to60Comorbidities","2ndDosageCovishield45to60Comorbidities","1stDosageCovishield60+Comorbidities","2ndDosageCovishield60+Comorbidities","Total1stDoseCovishield","Total2ndDoseCovishield","Date"]
print("headers\n", headers)
# Out:
# headers
#  ['S.No', 'Health_Unit_District', '1stDosageCovishieldHCW', '2ndDosageCovishieldHCW', '1stDosageCovishieldFLW', '2ndDosageCovishieldFLW', '1stDoseCovishield18to44', '2ndDoseCovishield18to44', '1stDoseCovishield45to60Comorbidities', '2ndDosageCovishield45to60Comorbidities', '1stDosageCovishield60+Comorbidities', '2ndDosageCovishield60+Comorbidities', 'Total1stDoseCovishield', 'Total2ndDoseCovishield', 'Date']

# %%
df.columns = headers
df.head(10)
# Out:
#    S.No  Health_Unit_District  1stDosageCovishieldHCW  \
# 0  S.No  Health Unit District  1stDosageCovishieldHCW
# 1     1            Aranthangi                    2364
# 2     2            Aranthangi                    2365
# 3     3            Aranthangi                    2365
# 4     4              Ariyalur                    4044
# 5     5              Ariyalur                    4044
# 6     6              Ariyalur                    4044
# 7     7                 Attur                    5542
# 8     8                 Attur                    5542
# 9     9                 Attur                    5542
#
#     2ndDosageCovishieldHCW   1stDosageCovishieldFLW  2ndDosageCovishieldFLW  \
# 0   2ndDosageCovishieldHCW   1stDosageCovishieldFLW  2ndDosageCovishieldFLW
# 1                     1226                     2171                     802
# 2                     1226                     2172                     803
# 3                     1226                     2173                     835
# 4                     2577                     8940                    4473
# 5                     2577                     8954                    4473
# 6                     2578                     8954                    4473
# 7                     4869                     9922                    3644
# 8                     4874                     9922                    3644
# 9                     4874                     9922                    3645
#
#    1stDoseCovishield18to44    2ndDoseCovishield18to44  \
# 0  1stDoseCovishield18to44   2ndDoseCovishield18to44
# 1                      210                          0
# 2                     1560                          0
# 3                     4248                          0
# 4                      385                          0
# 5                     2079                          0
# 6                     3486                          0
# 7                     1235                          0
# 8                     6404                          0
# 9                     9516                          0
#
#    1stDoseCovishield45to60Comorbidities  \
# 0  1stDoseCovishield45to60Comorbidities
# 1                                 15407
# 2                                 15709
# 3                                 15886
# 4                                 16008
# 5                                 16453
# 6                                 16700
# 7                                 65777
# 8                                 66400
# 9                                 66912
#
#     2ndDosageCovishield45to60Comorbidities  \
# 0   2ndDosageCovishield45to60Comorbidities
# 1                                     4002
# 2                                     4020
# 3                                     4028
# 4                                     2783
# 5                                     2786
# 6                                     2793
# 7                                    17566
# 8                                    17625
# 9                                    17700
#
#    1stDosageCovishield60+Comorbidities  2ndDosageCovishield60+Comorbidities  \
# 0  1stDosageCovishield60+Comorbidities  2ndDosageCovishield60+Comorbidities
# 1                                 9623                                 2409
# 2                                 9681                                 2412
# 3                                 9741                                 2415
# 4                                11216                                 2595
# 5                                11403                                 2601
# 6                                11493                                 2601
# 7                                38731                                10427
# 8                                38880                                10444
# 9                                39009                                10459
#
#    Total1stDoseCovishield  Total2ndDoseCovishield        Date
# 0  Total1stDoseCovishield  Total2ndDoseCovishield        Date
# 1                   29775                    8439  24-05-2021
# 2                   31487                    8461  25-05-2021
# 3                   34413                    8504  26-05-2021
# 4                   40593                   12428  24-05-2021
# 5                   42933                   12437  25-05-2021
# 6                   44677                   12445  26-05-2021
# 7                  121207                   36506  24-05-2021
# 8                  127148                   36587  25-05-2021
# 9                  130901                   36678  26-05-2021

# %%
df = df.iloc[1: , :]

# %%
df.head(9)
# Out:
#   S.No Health_Unit_District 1stDosageCovishieldHCW 2ndDosageCovishieldHCW  \
# 1    1           Aranthangi                   2364                   1226
# 2    2           Aranthangi                   2365                   1226
# 3    3           Aranthangi                   2365                   1226
# 4    4             Ariyalur                   4044                   2577
# 5    5             Ariyalur                   4044                   2577
# 6    6             Ariyalur                   4044                   2578
# 7    7                Attur                   5542                   4869
# 8    8                Attur                   5542                   4874
# 9    9                Attur                   5542                   4874
#
#   1stDosageCovishieldFLW 2ndDosageCovishieldFLW 1stDoseCovishield18to44  \
# 1                   2171                    802                     210
# 2                   2172                    803                    1560
# 3                   2173                    835                    4248
# 4                   8940                   4473                     385
# 5                   8954                   4473                    2079
# 6                   8954                   4473                    3486
# 7                   9922                   3644                    1235
# 8                   9922                   3644                    6404
# 9                   9922                   3645                    9516
#
#   2ndDoseCovishield18to44 1stDoseCovishield45to60Comorbidities  \
# 1                       0                                15407
# 2                       0                                15709
# 3                       0                                15886
# 4                       0                                16008
# 5                       0                                16453
# 6                       0                                16700
# 7                       0                                65777
# 8                       0                                66400
# 9                       0                                66912
#
#   2ndDosageCovishield45to60Comorbidities 1stDosageCovishield60+Comorbidities  \
# 1                                   4002                                9623
# 2                                   4020                                9681
# 3                                   4028                                9741
# 4                                   2783                               11216
# 5                                   2786                               11403
# 6                                   2793                               11493
# 7                                  17566                               38731
# 8                                  17625                               38880
# 9                                  17700                               39009
#
#   2ndDosageCovishield60+Comorbidities Total1stDoseCovishield  \
# 1                                2409                  29775
# 2                                2412                  31487
# 3                                2415                  34413
# 4                                2595                  40593
# 5                                2601                  42933
# 6                                2601                  44677
# 7                               10427                 121207
# 8                               10444                 127148
# 9                               10459                 130901
#
#   Total2ndDoseCovishield        Date
# 1                   8439  24-05-2021
# 2                   8461  25-05-2021
# 3                   8504  26-05-2021
# 4                  12428  24-05-2021
# 5                  12437  25-05-2021
# 6                  12445  26-05-2021
# 7                  36506  24-05-2021
# 8                  36587  25-05-2021
# 9                  36678  26-05-2021

# %%
df.dtypes
# Out:
# S.No                                      object
# Health_Unit_District                      object
# 1stDosageCovishieldHCW                    object
# 2ndDosageCovishieldHCW                    object
# 1stDosageCovishieldFLW                    object
# 2ndDosageCovishieldFLW                    object
# 1stDoseCovishield18to44                   object
# 2ndDoseCovishield18to44                   object
# 1stDoseCovishield45to60Comorbidities      object
# 2ndDosageCovishield45to60Comorbidities    object
# 1stDosageCovishield60+Comorbidities       object
# 2ndDosageCovishield60+Comorbidities       object
# Total1stDoseCovishield                    object
# Total2ndDoseCovishield                    object
# Date                                      object
# dtype: object

# %%
df['S.No'] = df['S.No'].astype('int64')
df['1stDosageCovishieldHCW'] = df['1stDosageCovishieldHCW'].astype('int64')
df['2ndDosageCovishieldHCW'] = df['2ndDosageCovishieldHCW'].astype('int64')
df['1stDosageCovishieldFLW'] = df['1stDosageCovishieldFLW'].astype('int64')
df['2ndDosageCovishieldFLW'] = df['2ndDosageCovishieldFLW'].astype('int64')
df['1stDoseCovishield18to44'] = df['1stDoseCovishield18to44'].astype('int64')
df['2ndDoseCovishield18to44'] = df['2ndDoseCovishield18to44'].astype('int64')
df['1stDoseCovishield45to60Comorbidities'] = df['1stDoseCovishield45to60Comorbidities'].astype('int64')
df['2ndDosageCovishield45to60Comorbidities'] = df['2ndDosageCovishield45to60Comorbidities'].astype('int64')
df['1stDosageCovishield60+Comorbidities'] = df['1stDosageCovishield60+Comorbidities'].astype('int64')
df['2ndDosageCovishield60+Comorbidities'] = df['2ndDosageCovishield60+Comorbidities'].astype('int64')
df['Total1stDoseCovishield'] = df['Total1stDoseCovishield'].astype('int64')
df['Total2ndDoseCovishield'] = df['Total2ndDoseCovishield'].astype('int64')

# %%
df.dtypes
# Out:
# S.No                                       int64
# Health_Unit_District                      object
# 1stDosageCovishieldHCW                     int64
# 2ndDosageCovishieldHCW                     int64
# 1stDosageCovishieldFLW                     int64
# 2ndDosageCovishieldFLW                     int64
# 1stDoseCovishield18to44                    int64
# 2ndDoseCovishield18to44                    int64
# 1stDoseCovishield45to60Comorbidities       int64
# 2ndDosageCovishield45to60Comorbidities     int64
# 1stDosageCovishield60+Comorbidities        int64
# 2ndDosageCovishield60+Comorbidities        int64
# Total1stDoseCovishield                     int64
# Total2ndDoseCovishield                     int64
# Date                                      object
# dtype: object

# %%
#data visualisation

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
df1=df.head(10)

# %%
df1.plot(x="Health_Unit_District", y="1stDoseCovishield18to44", kind="bar")
# Out:
# <AxesSubplot:xlabel='Health_Unit_District'>

# %%
date_set = set(df1['Date'])

plt.figure()
for Date in date_set:
     selected_data = df1.loc[df1['Date'] == Date]
     plt.plot(selected_data['Health_Unit_District'], selected_data['1stDoseCovishield18to44'], label=Date)
     
plt.legend()
plt.show()

# %%
#Predicting a particulars number using linear regression

# %%
from sklearn.model_selection import train_test_split
import datetime as dt
df['Date'] = pd.to_datetime(df['Date'])
df.head(3)
# Out:
#    S.No Health_Unit_District  1stDosageCovishieldHCW  2ndDosageCovishieldHCW  \
# 1     1           Aranthangi                    2364                    1226
# 2     2           Aranthangi                    2365                    1226
# 3     3           Aranthangi                    2365                    1226
#
#    1stDosageCovishieldFLW  2ndDosageCovishieldFLW  1stDoseCovishield18to44  \
# 1                    2171                     802                      210
# 2                    2172                     803                     1560
# 3                    2173                     835                     4248
#
#    2ndDoseCovishield18to44  1stDoseCovishield45to60Comorbidities  \
# 1                        0                                 15407
# 2                        0                                 15709
# 3                        0                                 15886
#
#    2ndDosageCovishield45to60Comorbidities  \
# 1                                    4002
# 2                                    4020
# 3                                    4028
#
#    1stDosageCovishield60+Comorbidities  2ndDosageCovishield60+Comorbidities  \
# 1                                 9623                                 2409
# 2                                 9681                                 2412
# 3                                 9741                                 2415
#
#    Total1stDoseCovishield  Total2ndDoseCovishield       Date
# 1                   29775                    8439 2021-05-24
# 2                   31487                    8461 2021-05-25
# 3                   34413                    8504 2021-05-26

# %%
#converting date time to ordinal
df['Date']=df['Date'].map(dt.datetime.toordinal)
df.head(3)
# Out:
#    S.No Health_Unit_District  1stDosageCovishieldHCW  2ndDosageCovishieldHCW  \
# 1     1           Aranthangi                    2364                    1226
# 2     2           Aranthangi                    2365                    1226
# 3     3           Aranthangi                    2365                    1226
#
#    1stDosageCovishieldFLW  2ndDosageCovishieldFLW  1stDoseCovishield18to44  \
# 1                    2171                     802                      210
# 2                    2172                     803                     1560
# 3                    2173                     835                     4248
#
#    2ndDoseCovishield18to44  1stDoseCovishield45to60Comorbidities  \
# 1                        0                                 15407
# 2                        0                                 15709
# 3                        0                                 15886
#
#    2ndDosageCovishield45to60Comorbidities  \
# 1                                    4002
# 2                                    4020
# 3                                    4028
#
#    1stDosageCovishield60+Comorbidities  2ndDosageCovishield60+Comorbidities  \
# 1                                 9623                                 2409
# 2                                 9681                                 2412
# 3                                 9741                                 2415
#
#    Total1stDoseCovishield  Total2ndDoseCovishield    Date
# 1                   29775                    8439  737934
# 2                   31487                    8461  737935
# 3                   34413                    8504  737936

# %%
x=df['Date'].tail(3)
y=df['1stDoseCovishield18to44'].tail(3)
# Out:
#   File "<ipython-input-122-216acce93457>", line 1
#     x=df['Date'].(10:12)
#                  ^
# SyntaxError: invalid syntax

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
import numpy as np
lr.fit(np.array(x_train).reshape(-1,1),np.array(y_train).reshape(-1,1))
# Out:
# LinearRegression()

# %%
df.tail(3)
# Out:
#      S.No Health_Unit_District  1stDosageCovishieldHCW  \
# 133   133         Virudhunagar                    4145
# 134   134         Virudhunagar                    4156
# 135   135         Virudhunagar                    4159
#
#      2ndDosageCovishieldHCW  1stDosageCovishieldFLW  2ndDosageCovishieldFLW  \
# 133                    2207                    9137                    3568
# 134                    2207                    9163                    3582
# 135                    2210                    9233                    3585
#
#      1stDoseCovishield18to44  2ndDoseCovishield18to44  \
# 133                      314                        0
# 134                     2218                        0
# 135                     3723                        0
#
#      1stDoseCovishield45to60Comorbidities  \
# 133                                 34690
# 134                                 35017
# 135                                 35266
#
#      2ndDosageCovishield45to60Comorbidities  \
# 133                                   13930
# 134                                   13958
# 135                                   13964
#
#      1stDosageCovishield60+Comorbidities  2ndDosageCovishield60+Comorbidities  \
# 133                                22853                                 8064
# 134                                22911                                 8071
# 135                                22997                                 8076
#
#      Total1stDoseCovishield  Total2ndDoseCovishield    Date
# 133                   71139                   27769  737934
# 134                   73465                   27818  737935
# 135                   75378                   27835  737936

# %%
y_pred=lr.predict(np.array(x_test).reshape(-1,1))

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(x_test,y_pred)
# Out:
# 538482986596.0

# %%
lr.predict(np.array([[737937]])) #that is may of 27
# Out:
# array([[6026.]])

# %%
#actual number on 27th of may 2022 is 5874
